# %% [markdown]
# <a href="https://colab.research.google.com/github/GenaroHacker/skill_builder_exams/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Set Up
# %%capture
# !git clone https://github.com/GenaroHacker/skill_builder_exams.git

from skill_builder_exams.sql import insert_exam
from skill_builder_exams.sql import read_all_exams
from skill_builder_exams.sql import delete_exam
from skill_builder_exams.sql import delete_all_exams
from skill_builder_exams.sql import print_all_exams
from skill_builder_exams.practice import practice
from skill_builder_exams.read_dict_exams import process_and_insert_exams_from_directory

# %%
#@title Practice
TAG = "example_tag" # @param {type:"string"}
#delete_exam("python")
#delete_all_exams()
process_and_insert_exams_from_directory()
insert_exam("your_exam_here","example_tag",{"1 + 1":"2", "1 - 1":"0"})
print_all_exams()
practice([TAG]) # Filter exams by tag
# Out:
# TAG                                   EXAM                                      QUESTIONS
# ---------------------------------------------------------------------------------------------
# design_pattern_aspects_that_vary      creational_pattern_aspects_that_vary      5
# design_pattern_aspects_that_vary      structural_pattern_aspects_that_vary      7
# design_pattern_aspects_that_vary      behavioral_pattern_aspects_that_vary      11
# design_pattern_definitions            creational_pattern_definitions            5
# design_pattern_definitions            structural_pattern_definitions            7
# design_pattern_definitions            behavioral_pattern_definitions            11
# design_pattern_participants           creational_patterns_participants          5
# design_pattern_participants           structural_patterns_participants          7
# design_pattern_participants           behavioral_patterns_participants          11
# example_tag                           your_exam_here                            2
# guitar                                music_intervals                           25
# guitar                                intervals_to_semitones                    26
# guitar                                semitones_to_intervals                    14
#
# 3 exams selected.
#
# Do you want to practice behavioral_patterns_participants? (y/n) 11 questions.
# n
# Skipping ---behavioral_patterns_participants---
#
# Do you want to practice creational_patterns_participants? (y/n) 5 questions.
# y
# Practicing ---creational_patterns_participants---
#  ---->  Builder?
#  <---- abstractbuilder, concretebuilder, director, client
#  ---->  ✘
#  ---->  The correct answer is "BUILDER, CONCRETEBUILDER, DIRECTOR, PRODUCT"
#
#  ---->  Builder?
#  <---- builder, concretebuilder, director, product
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Abstract Factory?
#  <---- abstractfactory, concretefactory, abstractproduct, concreteproduct, client
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Prototype?
#  <---- abstractprototype, concreteprototype, client
#  ---->  ✘
#  ---->  The correct answer is "PROTOTYPE, CONCRETEPROTOTYPE, CLIENT"
#
#  ---->  Prototype?
#  <---- prototype, concreteprototype, client
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Factory Method?
#  <---- abstractfactory, concretefactory, abstractproduct, concreteproduct, client
#  ---->  ✘
#  ---->  The correct answer is "CREATOR, CONCRETECREATOR, PRODUCT, CONCRETEPRODUCT"
#
#  ---->  Factory Method?
#  <---- creator, concretecreator, product, concreteproduct
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Singleton?
#  <---- singleton
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Builder?
#  <---- abstractbuilder, concretebuilder, director, client
#  ---->  ✘
#  ---->  The correct answer is "BUILDER, CONCRETEBUILDER, DIRECTOR, PRODUCT"
#
#  ---->  Builder?
#  <---- builder, concretebuilder, director, product
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Prototype?
#  <---- abstractprototype, concreteprototype, client
#  ---->  ✘
#  ---->  The correct answer is "PROTOTYPE, CONCRETEPROTOTYPE, CLIENT"
#
#  ---->  Prototype?
#  <---- prototype, concreteprototype, client
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Factory Method?
#  <---- creator, abstractcreator, product
#  ---->  ✘
#  ---->  The correct answer is "CREATOR, CONCRETECREATOR, PRODUCT, CONCRETEPRODUCT"
#
#  ---->  Factory Method?
#  <---- creator, concretecreator, product, concreteproduct
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Prototype?
#  <---- prototype, concreteprototype, client
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Builder?
#  <---- builder, concretebuilder, director, product
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#  ---->  Factory Method?
#  <---- creator, concretecreator, product, concreteproduct
#  ---->  ✔
#
#
#
#
#
#
#
#
#
#
#
#
# -------------------------------------------------------------------------
# creational_patterns_participants test finished.
# Your score was: 2/5
# Time taken: 4 minutes and 53 seconds
# -------------------------------------------------------------------------
#
#
# Do you want to practice structural_patterns_participants? (y/n) 7 questions.
# n
# Skipping ---structural_patterns_participants---
