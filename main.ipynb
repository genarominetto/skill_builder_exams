# %% [markdown]
# <a href="https://colab.research.google.com/github/GenaroHacker/skill_builder_exams/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Set Up
# %%capture
# !git clone https://github.com/GenaroHacker/skill_builder_exams.git

from skill_builder_exams.sql import insert_exam
from skill_builder_exams.sql import read_all_exams
from skill_builder_exams.sql import delete_exam
from skill_builder_exams.sql import delete_all_exams
from skill_builder_exams.sql import print_all_exams
from skill_builder_exams.practice import practice

# %%
#@title Practice
#delete_exam("python")
#delete_all_exams()
insert_exam("your_exam_here","example_tag",{"1 + 1":"2", "1 - 1":"0"})
print_all_exams()
practice(["design_patterns"]) # Filter exams by tag
# Out:
# TAG             EXAM            QUESTIONS
# ----------------------------------------
# bash            bash            5
# design_patterns vary_aspects    23
# design_patterns descriptions    23
# docker          docker_basics   8
# example_tag     your_exam_here  2
# guitar          music_intervals 25
# guitar          semitones       26
# programming     oop             5
# python          python          5
# python          python_2        5
# sql             crud            4
#
# 2 exams selected.
#
# Do you want to practice vary_aspects? (y/n) 23 questions.
# y
# Practicing ---vary_aspects---
#  ---->  Template Method?
#  <---- the steps of a method
#  ---->  ✘
#  ---->  The correct answer is "STEPS OF AN ALGORITHM"
#
#  ---->  Template Method?
#  <---- steps of an algorithm
#  ---->  ✔
#
#  ---->  Decorator?
#  <---- the functionality added tho the class
#  ---->  ✘
#  ---->  The correct answer is "RESPONSIBILITIES OF AN OBJECT WITHOUT SUBCLASSING"
#
#  ---->  Decorator?
#  <---- responibilities of an object without subclassing
#  ---->  ✘
#  ---->  The correct answer is "RESPONSIBILITIES OF AN OBJECT WITHOUT SUBCLASSING"
#
#  ---->  Decorator?
#  <---- responsibilities of an object without subclassing
#  ---->  ✔
#
#  ---->  Iterator?
#  <---- how to walk trough an aggregate
#  ---->  ✘
#  ---->  The correct answer is "HOW THE ELEMENTS OF AN AGGREGATE ARE ACCESSED"
#
#  ---->  Iterator?
#  <---- how the elements of an aggregate are accessed
#  ---->  ✔
#
#  ---->  Interpreter?
#  <---- the grammar and how it is interpreted
#  ---->  ✘
#  ---->  The correct answer is "GRAMMAR AND INTERPRETATION OF A LANGUAGE"
#
#  ---->  Interpreter?
#  <---- grammar and interpretation of a language
#  ---->  ✔
#
#  ---->  Facade?
#  <---- how is it related to the system
#  ---->  ✘
#  ---->  The correct answer is "INTERFACE TO A SUBSYSTEM"
#
#  ---->  Facade?
#  <---- interface to a subsystem
#  ---->  ✔
#
#  ---->  Adapter?
#  <---- the communicateion between two objects
#  ---->  ✘
#  ---->  The correct answer is "INTERFACE TO AN OBJECT"
#
#  ---->  Adapter?
#  <---- interface to an object
#  ---->  ✔
#
#  ---->  Composite?
#  <---- the structure of the object
#  ---->  ✘
#  ---->  The correct answer is "STRUCTURE AND COMPOSITION OF AN OBJECT"
#
#  ---->  Composite?
#  <---- structure and composition of an object
#  ---->  ✔
#
#  ---->  Singleton?
#  <---- the only instance of a class
#  ---->  ✘
#  ---->  The correct answer is "THE SINGLE INSTANCE OF A CLASS"
#
#  ---->  Singleton?
#  <---- the single instance of a class
#  ---->  ✔
#
#  ---->  Strategy?
#  <---- the methods at runtime
#  ---->  ✘
#  ---->  The correct answer is "AN ALGORITHM"
#
#  ---->  Strategy?
#  <---- an algorithm
#  ---->  ✔
#
#  ---->  Chain of Responsibility?
#  <---- who and when a command is performed
#  ---->  ✘
#  ---->  The correct answer is "OBJECT THAT CAN PROCESS A REQUEST"
#
#  ---->  Chain of Responsibility?
#  <---- object that can process a request
#  ---->  ✔
#
#  ---->  Command?
#  <---- how and when a request is executed
#  ---->  ✘
#  ---->  The correct answer is "WHEN AND HOW A REQUEST IS PROCESSED"
#
#  ---->  Command?
#  <---- when and how a request is processed
#  ---->  ✔
#
#  ---->  Factory Method?
#  <---- how a family of objects is created and who perform the request
#  ---->  ✘
#  ---->  The correct answer is "SUBCLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Factory Method?
#  <---- subclass of object that is instantiated
#  ---->  ✔
#
#  ---->  Bridge?
#  <---- how two groups are connected
#  ---->  ✘
#  ---->  The correct answer is "IMPLEMENTATION OF AN OBJECT"
#
#  ---->  Bridge?
#  <---- implementation of an object
#  ---->  ✔
#
#  ---->  State?
#  <---- the states of an object
#  ---->  ✘
#  ---->  The correct answer is "STATES OF AN OBJECT"
#
#  ---->  State?
#  <---- states of an object
#  ---->  ✔
#
#  ---->  Proxy?
#  <---- the representant of an object
#  ---->  ✘
#  ---->  The correct answer is "HOW AN OBJECT IS ACCESSED"
#
#  ---->  Proxy?
#  <---- how an object is accessed
#  ---->  ✔
#
#  ---->  Builder?
#  <---- how an object is constructed
#  ---->  ✘
#  ---->  The correct answer is "HOW A COMPOSITE OBJECT GETS CREATED"
#
#  ---->  Builder?
#  <---- how a composite object gets created
#  ---->  ✔
#
#  ---->  Mediator?
#  <---- how multiple objects talk to each other
#  ---->  ✘
#  ---->  The correct answer is "HOW AND WHICH OBJECTS INTERACT WITH EACH OTHER"
#
#  ---->  Mediator?
#  <---- how and which objects interact with each other
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- what parts of an object are copyed
#  ---->  ✘
#  ---->  The correct answer is "CLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Flyweight?
#  <---- how shared objects are loaded
#  ---->  ✘
#  ---->  The correct answer is "STORAGE COSTS OF OBJECTS"
#
#  ---->  Flyweight?
#  <---- storage costs of objects
#  ---->  ✔
#
#  ---->  Memento?
#  <---- how and when to store the internal state of an object
#  ---->  ✘
#  ---->  The correct answer is "WHAT PRIVATE INFORMATION IS STORED OUTSIDE AN OBJECT"
#
#  ---->  Memento?
#  <---- what private information is stored outside an object
#  ---->  ✔
#
#  ---->  Observer?
#  <---- what observers see the subject
#  ---->  ✘
#  ---->  The correct answer is "HOW THE DEPENDENT OBJECTS STAY UP TO DATE"
#
#  ---->  Observer?
#  <---- how the dependent objects stay up to date
#  ---->  ✔
#
#  ---->  Abstract Factory?
#  <---- wich subclass creates an object
#  ---->  ✘
#  ---->  The correct answer is "FAMILIES OF PRODUCT OBJECTS"
#
#  ---->  Abstract Factory?
#  <---- families of product objects
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- how an object changes another
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#  ---->  Strategy?
#  <---- the selected algorithm
#  ---->  ✘
#  ---->  The correct answer is "AN ALGORITHM"
#
#  ---->  Strategy?
#  <---- an algorithm
#  ---->  ✔
#
#  ---->  Mediator?
#  <---- how and wich objects interact with each other
#  ---->  ✘
#  ---->  The correct answer is "HOW AND WHICH OBJECTS INTERACT WITH EACH OTHER"
#
#  ---->  Mediator?
#  <---- how and which objects interact with each other
#  ---->  ✔
#
#  ---->  Decorator?
#  <---- how to add methods to another class
#  ---->  ✘
#  ---->  The correct answer is "RESPONSIBILITIES OF AN OBJECT WITHOUT SUBCLASSING"
#
#  ---->  Decorator?
#  <---- responsibilities of an object without subclassing
#  ---->  ✔
#
#  ---->  Observer?
#  <---- how an object stays up to date
#  ---->  ✘
#  ---->  The correct answer is "HOW THE DEPENDENT OBJECTS STAY UP TO DATE"
#
#  ---->  Observer?
#  <---- how the dependent objects stay up to date
#  ---->  ✔
#
#  ---->  Bridge?
#  <---- implementation of an object
#  ---->  ✔
#
#  ---->  Memento?
#  <---- how an object is accessed
#  ---->  ✘
#  ---->  The correct answer is "WHAT PRIVATE INFORMATION IS STORED OUTSIDE AN OBJECT"
#
#  ---->  Memento?
#  <---- what priveate information is stored outside an object
#  ---->  ✘
#  ---->  The correct answer is "WHAT PRIVATE INFORMATION IS STORED OUTSIDE AN OBJECT"
#
#  ---->  Memento?
#  <---- what private information is stored outside an object
#  ---->  ✔
#
#  ---->  Builder?
#  <---- how a composed object is created
#  ---->  ✘
#  ---->  The correct answer is "HOW A COMPOSITE OBJECT GETS CREATED"
#
#  ---->  Builder?
#  <---- how a composite object gets created
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- what information of an object is changed
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#  ---->  Adapter?
#  <---- an interface
#  ---->  ✘
#  ---->  The correct answer is "INTERFACE TO AN OBJECT"
#
#  ---->  Adapter?
#  <---- interface to an object
#  ---->  ✔
#
#  ---->  Abstract Factory?
#  <---- how a family of objects is created
#  ---->  ✘
#  ---->  The correct answer is "FAMILIES OF PRODUCT OBJECTS"
#
#  ---->  Abstract Factory?
#  <---- families of product objects
#  ---->  ✔
#
#  ---->  Command?
#  <---- when and how a request is processed
#  ---->  ✔
#
#  ---->  Flyweight?
#  <---- storage costs of an object
#  ---->  ✘
#  ---->  The correct answer is "STORAGE COSTS OF OBJECTS"
#
#  ---->  Flyweight?
#  <---- storage costs of objects
#  ---->  ✔
#
#  ---->  State?
#  <---- state of an object
#  ---->  ✘
#  ---->  The correct answer is "STATES OF AN OBJECT"
#
#  ---->  State?
#  <---- states of an object
#  ---->  ✔
#
#  ---->  Iterator?
#  <---- how an aggregate is accessed
#  ---->  ✘
#  ---->  The correct answer is "HOW THE ELEMENTS OF AN AGGREGATE ARE ACCESSED"
#
#  ---->  Iterator?
#  <---- how the elements of an aggregate are accessed
#  ---->  ✔
#
#  ---->  Interpreter?
#  <---- the grammar and interpretation of a langage
#  ---->  ✘
#  ---->  The correct answer is "GRAMMAR AND INTERPRETATION OF A LANGUAGE"
#
#  ---->  Interpreter?
#  <---- grammar and interpretation of a language
#  ---->  ✔
#
#  ---->  Facade?
#  <---- interface to a subsystem
#  ---->  ✔
#
#  ---->  Composite?
#  <---- structure of an object
#  ---->  ✘
#  ---->  The correct answer is "STRUCTURE AND COMPOSITION OF AN OBJECT"
#
#  ---->  Composite?
#  <---- structure and composition of an object
#  ---->  ✔
#
#  ---->  Chain of Responsibility?
#  <---- who perform a request
#  ---->  ✘
#  ---->  The correct answer is "OBJECT THAT CAN PROCESS A REQUEST"
#
#  ---->  Chain of Responsibility?
#  <---- object that can process a request
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- type of an object
#  ---->  ✘
#  ---->  The correct answer is "CLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Singleton?
#  <---- the single instance of an object
#  ---->  ✘
#  ---->  The correct answer is "THE SINGLE INSTANCE OF A CLASS"
#
#  ---->  Singleton?
#  <---- the single instance of a class
#  ---->  ✔
#
#  ---->  Proxy?
#  <---- how to access an object
#  ---->  ✘
#  ---->  The correct answer is "HOW AN OBJECT IS ACCESSED"
#
#  ---->  Proxy?
#  <---- how an object is accessed
#  ---->  ✔
#
#  ---->  Factory Method?
#  <---- which subclass executes a method
#  ---->  ✘
#  ---->  The correct answer is "SUBCLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Factory Method?
#  <---- subclass of  object that is instantiated
#  ---->  ✘
#  ---->  The correct answer is "SUBCLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Factory Method?
#  <---- subclass of object that is instantiated
#  ---->  ✔
#
#  ---->  Template Method?
#  <---- steps of an algorithm
#  ---->  ✔
#
#  ---->  Observer?
#  <---- how the dependent object is up to date
#  ---->  ✘
#  ---->  The correct answer is "HOW THE DEPENDENT OBJECTS STAY UP TO DATE"
#
#  ---->  Observer?
#  <---- how the dependentt objects stay up to date
#  ---->  ✘
#  ---->  The correct answer is "HOW THE DEPENDENT OBJECTS STAY UP TO DATE"
#
#  ---->  Observer?
#  <---- how the dependent objects stay up to date
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- class of object to instantiate
#  ---->  ✘
#  ---->  The correct answer is "CLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- operations to apply to an object without changing it
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#  ---->  Abstract Factory?
#  <---- families of product objects
#  ---->  ✔
#
#  ---->  Iterator?
#  <---- how the elements of an aggregate are accessed
#  ---->  ✔
#
#  ---->  Flyweight?
#  <---- storage costs of objects
#  ---->  ✔
#
#  ---->  Builder?
#  <---- how a composed object gets created
#  ---->  ✘
#  ---->  The correct answer is "HOW A COMPOSITE OBJECT GETS CREATED"
#
#  ---->  Builder?
#  <---- how a composite object gets created
#  ---->  ✔
#
#  ---->  State?
#  <---- states of an object
#  ---->  ✔
#
#  ---->  Memento?
#  <---- what private of an object is stored outside of it
#  ---->  ✘
#  ---->  The correct answer is "WHAT PRIVATE INFORMATION IS STORED OUTSIDE AN OBJECT"
#
#  ---->  Memento?
#  <---- what private information is stored outside an object
#  ---->  ✔
#
#  ---->  Composite?
#  <---- structure and composition of an object
#  ---->  ✔
#
#  ---->  Singleton?
#  <---- the single instance of a class
#  ---->  ✔
#
#  ---->  Adapter?
#  <---- interface to an object
#  ---->  ✔
#
#  ---->  Decorator?
#  <---- add methods to a class
#  ---->  ✘
#  ---->  The correct answer is "RESPONSIBILITIES OF AN OBJECT WITHOUT SUBCLASSING"
#
#  ---->  Decorator?
#  <---- responsibilities of an object without subclassing
#  ---->  ✔
#
#  ---->  Interpreter?
#  <---- grammar and interpretation of a language
#  ---->  ✔
#
#  ---->  Strategy?
#  <---- an algorithm
#  ---->  ✔
#
#  ---->  Factory Method?
#  <---- which subclass executes the method
#  ---->  ✘
#  ---->  The correct answer is "SUBCLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Factory Method?
#  <---- subclass of object that is instantiated
#  ---->  ✔
#
#  ---->  Proxy?
#  <---- how an object is accessed
#  ---->  ✔
#
#  ---->  Chain of Responsibility?
#  <---- which object perform the request
#  ---->  ✘
#  ---->  The correct answer is "OBJECT THAT CAN PROCESS A REQUEST"
#
#  ---->  Chain of Responsibility?
#  <---- object that can process a request
#  ---->  ✔
#
#  ---->  Mediator?
#  <---- which and how objects comunicate to each other
#  ---->  ✘
#  ---->  The correct answer is "HOW AND WHICH OBJECTS INTERACT WITH EACH OTHER"
#
#  ---->  Mediator?
#  <---- how and which objects interact with each other
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- class of an object is instantiated
#  ---->  ✘
#  ---->  The correct answer is "CLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Factory Method?
#  <---- subclass of an object to instantiate
#  ---->  ✘
#  ---->  The correct answer is "SUBCLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Factory Method?
#  <---- subclass of object that is instantiated
#  ---->  ✔
#
#  ---->  Decorator?
#  <---- responsibilities of an object without subclassing
#  ---->  ✔
#
#  ---->  Observer?
#  <---- how dependent objects stay up to date
#  ---->  ✘
#  ---->  The correct answer is "HOW THE DEPENDENT OBJECTS STAY UP TO DATE"
#
#  ---->  Observer?
#  <---- how the dependent objects stay up to date
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- operations that can be applied to an object
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#  ---->  Builder?
#  <---- how a composite object gets created
#  ---->  ✔
#
#  ---->  Chain of Responsibility?
#  <---- object that can solve a request
#  ---->  ✘
#  ---->  The correct answer is "OBJECT THAT CAN PROCESS A REQUEST"
#
#  ---->  Chain of Responsibility?
#  <---- object that can process a request
#  ---->  ✔
#
#  ---->  Memento?
#  <---- how the private information is stored outside an object
#  ---->  ✘
#  ---->  The correct answer is "WHAT PRIVATE INFORMATION IS STORED OUTSIDE AN OBJECT"
#
#  ---->  Memento?
#  <---- what private information is stored outside an object
#  ---->  ✔
#
#  ---->  Mediator?
#  <---- how and which objects interact with each other
#  ---->  ✔
#
#  ---->  Chain of Responsibility?
#  <---- object that can process a request
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their class
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing  their classes
#  ---->  ✘
#  ---->  The correct answer is "OPERATIONS THAT CAN BE APPLIED TO OBJECTS WITHOUT CHANGING THEIR CLASSES"
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- class of an object that is instantiated
#  ---->  ✘
#  ---->  The correct answer is "CLASS OF OBJECT THAT IS INSTANTIATED"
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Memento?
#  <---- what private information is stored outside an object
#  ---->  ✔
#
#  ---->  Factory Method?
#  <---- subclass of object that is instantiated
#  ---->  ✔
#
#  ---->  Observer?
#  <---- how the dependent objects stay up to date
#  ---->  ✔
#
#  ---->  Prototype?
#  <---- class of object that is instantiated
#  ---->  ✔
#
#  ---->  Visitor?
#  <---- operations that can be applied to objects without changing their classes
#  ---->  ✔
#
#
# -------------------------------------------------------------------------
# vary_aspects test finished.
# Your score was: 0/23
# Time taken: 72 minutes and 35 seconds
# -------------------------------------------------------------------------
#
#
# Do you want to practice descriptions? (y/n) 23 questions.
# n
# Skipping ---descriptions---
